# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data/Model_Performances.csv')
df.head()
# Out:
#                     Model  Move_number  Accuracy  Precision    Recall  \
# 0           Random Forest           10  0.536504   0.537241  0.537480
# 1       Gradient Boosting           10  0.517699   0.509688  0.509340
# 2  Support Vector Machine           10  0.548673   0.547213  0.514815
# 3           Random Forest           15  0.523230   0.520604  0.520652
# 4       Gradient Boosting           15  0.545354   0.539098  0.538002
#
#    F1-Score  Weighted Precision  Weighted Recall  Weighted F1-Score
# 0  0.536027            0.540645         0.536504           0.537245
# 1  0.507515            0.512875         0.517699           0.513312
# 2  0.430351            0.547357         0.548673           0.451603
# 3  0.520597            0.523843         0.523230           0.523505
# 4  0.537060            0.541854         0.545354           0.542132

# %%
# Configure seaborn style
sns.set(style="whitegrid")


# List of metrics to plot
metrics = ["Accuracy", "Weighted Precision", "Weighted Recall", "Weighted F1-Score"]

# Create a plot for each metric
plt.figure(figsize=(16, 12))
for i, metric in enumerate(metrics, 1):
    plt.subplot(2, 2, i)
    sns.lineplot(
        data=df,
        x="Move_number",
        y=metric,
        hue="Model",
        marker="o"
    )
    plt.title(f"{metric} vs Move count", fontsize=16)
    plt.xlabel("Move count", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    plt.legend(title="Model")
    plt.grid(visible=True)

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
# Configure seaborn style
sns.set(style="whitegrid")


# List of metrics to plot
metrics = ["Accuracy", "Weighted Precision", "Weighted Recall", "Weighted F1-Score"]

# Create a plot for each metric
plt.figure(figsize=(16, 12))
for i, metric in enumerate(metrics, 1):
    plt.subplot(2, 2, i)
    sns.lineplot(
        data=df,
        x="Move_number",
        y=metric,
        hue="Model",
        marker="o"
    )
    plt.title(f"{metric} vs Move ratio", fontsize=16)
    plt.xlabel("Move ratio (%)", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    plt.legend(title="Model")
    plt.grid(visible=True)

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
