# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data/Model_Performances.csv')
df.head()
# Out:
#                     Model  Move_number  Accuracy  Precision    Recall  \
# 0           Random Forest           10  0.498168   0.495465  0.495470
# 1       Gradient Boosting           10  0.487179   0.480614  0.481097
# 2  Support Vector Machine           10  0.527473   0.474617  0.495712
# 3           Random Forest           20  0.512821   0.510204  0.510193
# 4       Gradient Boosting           20  0.454212   0.442678  0.445664
#
#    F1-Score  Weighted Precision  Weighted Recall  Weighted F1-Score
# 0  0.495461            0.497911         0.498168           0.498033
# 1  0.479575            0.483268         0.487179           0.483953
# 2  0.377495            0.478650         0.527473           0.398760
# 3  0.510192            0.512571         0.512821           0.512689
# 4  0.440981            0.446049         0.454212           0.446967

# %%
# Configure seaborn style
sns.set(style="whitegrid")


# List of metrics to plot
metrics = ["Accuracy", "Weighted Precision", "Weighted Recall", "Weighted F1-Score"]

# Create a plot for each metric
plt.figure(figsize=(16, 12))
for i, metric in enumerate(metrics, 1):
    plt.subplot(2, 2, i)
    sns.lineplot(
        data=df,
        x="Move_number",
        y=metric,
        hue="Model",
        marker="o"
    )
    plt.title(f"{metric} vs Move Ratio", fontsize=16)
    plt.xlabel("Move Ratio (%)", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    plt.legend(title="Model")
    plt.grid(visible=True)

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
