# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data/Model_Performances.csv')
df.head()
# Out:
#                     Model  Move_number  Accuracy  Precision    Recall  \
# 0           Random Forest           10  0.511062   0.510072  0.510134
# 1       Gradient Boosting           10  0.514381   0.509108  0.509008
# 2  Support Vector Machine           10  0.537611   0.501289  0.500214
# 3           Random Forest           20  0.495575   0.492734  0.492719
# 4       Gradient Boosting           20  0.549779   0.541602  0.538628
#
#    F1-Score  Weighted Precision  Weighted Recall  Weighted F1-Score
# 0  0.509680            0.513402         0.511062           0.511811
# 1  0.508724            0.512359         0.514381           0.513039
# 2  0.385290            0.504543         0.537611           0.410338
# 3  0.492705            0.496125         0.495575           0.495828
# 4  0.534649            0.544003         0.549779           0.541518

# %%
# Configure seaborn style
sns.set(style="whitegrid")


# List of metrics to plot
metrics = ["Accuracy", "Weighted Precision", "Weighted Recall", "Weighted F1-Score"]

# Create a plot for each metric
plt.figure(figsize=(16, 12))
for i, metric in enumerate(metrics, 1):
    plt.subplot(2, 2, i)
    sns.lineplot(
        data=df,
        x="Move_number",
        y=metric,
        hue="Model",
        marker="o"
    )
    plt.title(f"{metric} vs Move Ratio", fontsize=16)
    plt.xlabel("Move Ratio (%)", fontsize=12)
    plt.ylabel(metric, fontsize=12)
    plt.legend(title="Model")
    plt.grid(visible=True)

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
